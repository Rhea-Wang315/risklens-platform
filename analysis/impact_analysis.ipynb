# %% [markdown]
# # RiskLens Week 2 Impact Analysis\n\nThis notebook runs the Week 2 case-study pipeline and renders core business-impact metrics.

# %%
from pathlib import Path\nimport json

# %%
from risklens.analysis.impact import run_impact_analysis

# %%
outputs = run_impact_analysis(\n    input_path=Path("analysis/data/sample_week2_alerts.jsonl"),\n    output_dir=Path("analysis/output"),\n    warn_review_seconds=3600,\n)\noutputs

# %%
summary = json.loads(Path(outputs["summary_json"]).read_text(encoding="utf-8"))\nsummary

# %% [markdown]
# ## Generated Artifacts\n\n- `analysis/output/decisions.csv`\n- `analysis/output/impact_summary.json`\n- `analysis/output/impact_summary.md`\n- `analysis/output/incident_report_draft.md`
